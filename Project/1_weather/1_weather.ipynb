# %% [markdown]
# 这个练习的数据集来源于：https://github.com/Swatikhedekar/Python-project-for-Data-anlytics-Beginners-

# %% [markdown]
# 1. 导入库

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams['font.family'] = 'SimHei'

# %% [markdown]
# 2. 导入数据

# %%
df = pd.read_csv('./Weather Data.csv')
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %% [markdown]
# 3. 绘制气温的趋势变化图

# %%
df['Date/Time'] = pd.to_datetime(df['Date/Time'])
plt.figure(figsize=(20, 20))
plt.plot(df['Date/Time'], df['Temp_C'], label='气温')
# plt.plot(df['Date/Time'], df['Dew Point Temp_C'], label='露点')
plt.title('2012年气温趋势变化图', fontsize=40)

plt.xticks(rotation=0, fontsize=25)
plt.yticks(rotation=0, fontsize=25)

plt.xlabel('日期', fontsize=30)
plt.ylabel('气温', fontsize=30)
plt.legend(fontsize=30)
# Out:
# C:\anaconda\envs\myenv\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   func(*args, **kwargs)
# C:\anaconda\envs\myenv\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# 4. 绘制潮湿度的直方图

# %%
plt.hist(df['Rel Hum_%'], bins=5)
# Out:
# (array([ 314., 1173., 2748., 2813., 1736.]),
#  array([ 18. ,  34.4,  50.8,  67.2,  83.6, 100. ]),
#  <BarContainer object of 5 artists>)
